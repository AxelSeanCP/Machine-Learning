# %% [markdown]
# # Image Classification: Multi Class
#
# > **Disclaimer ⚠️:**
# > - Demo ini sebatas referensi saja
# > - Tidak boleh asal copy paste terutama pada bagian dengan tanda **[Additional ⚠️]** karna berpotensi terkena **PLAGIARISM**.
#
# > Referensi Utama:
# - https://www.dicoding.com/academies/185/tutorials/10099
# - https://www.dicoding.com/academies/185/tutorials/10239
# - https://www.dicoding.com/academies/185/tutorials/10109
#
# > Referensi Tambahan:
#   - https://github.com/reevald/craftivity-data/blob/main/tflite-model-maker.ipynb

# %% [markdown]
# ## Kriteria Penilaian

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Importing Required Libraries

# %%
# For processing data
import os
import zipfile
import pathlib
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# For visualization
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.style.use('ggplot')

# %% [markdown]
# ## Download Dataset

# %%
# !wget --no-check-certificate \
    https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip \
    -O /tmp/Chessman-image-dataset.zip
# Out:
# --2024-01-04 08:28:45--  https://github.com/dicodingacademy/assets/raw/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip [following]
# --2024-01-04 08:28:45--  https://raw.githubusercontent.com/dicodingacademy/assets/main/ml_pengembangan_academy/Chessman-image-dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60684125 (58M) [application/zip]
# Saving to: ‘/tmp/Chessman-image-dataset.zip’
#
# /tmp/Chessman-image 100%[===================>]  57.87M   305MB/s    in 0.2s
#
# 2024-01-04 08:28:50 (305 MB/s) - ‘/tmp/Chessman-image-dataset.zip’ saved [60684125/60684125]

# %% [markdown]
# ## Load Data

# %%
local_zip = '/tmp/Chessman-image-dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('/tmp')
zip_ref.close()

# %% [markdown]
# ## Data Exploration

# %%
os.listdir('/tmp/Chessman-image-dataset/Chess')
# Out:
# ['Rook', 'Pawn', 'Bishop', 'Queen', 'Knight', 'King']

# %% [markdown]
# ### Data Distribution each Class

# %%
for label in os.listdir('/tmp/Chessman-image-dataset/Chess'):
  print(f'Total {label} images :', len(os.listdir(f'/tmp/Chessman-image-dataset/Chess/{label}')))
# Out:
# Total Rook images : 102
# Total Pawn images : 107
# Total Bishop images : 87
# Total Queen images : 78
# Total Knight images : 106
# Total King images : 76

# %% [markdown]
# ### Data Visualization

# %%
img = image.load_img('/tmp/Chessman-image-dataset/Chess/King/00000145.png')
imgplot = plt.imshow(img)

# %% [markdown]
# ## Data Augmentation + Split

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
base_dir = os.path.join('/tmp/Chessman-image-dataset/Chess')



train_datagen = ImageDataGenerator(rescale=1./255,
    # Tips untuk augmentasi, pertimbangkan gambar
    # apabila dirotasi, apakah akan merubah makna gambar
    # dan disesuaikan dengan kebutuhan ketika deployment
    # Contoh: jika kita dideploy di app, dan ketika memfoto boleh terbalik posisinya
    # maka data perlu diaugmentasi dengan flip vertical dan rotasi untuk menangani kasus tersebut
    # Contoh lain: Deteksi wajah, dimana posisi wajah harusnya tegak normal,
    # maka tidak perlu dilakukan rotasi yang terlalu besar begitupun flip (pilih horizontal jgn yang vertical)
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    fill_mode = 'nearest',
    validation_split=0.2 # 80% (train) : 20% (test)
) # set validation split

val_datagen = ImageDataGenerator(
    # Augmentasi pada validation cukup dilakukan rescaling nilai pixelnya saja
    # Sesuai saran dari Dicoding
    rescale=1./255,
    validation_split=0.2 # 80% (train) : 20% (test)
)

# %%
train_generator = train_datagen.flow_from_directory(
    base_dir,
    target_size=(150, 150),
    batch_size=8,
    class_mode='categorical',
    subset='training') # set as training data
validation_generator = val_datagen.flow_from_directory(
    base_dir, # same directory as training data
    target_size=(150, 150),
    batch_size=16,
    class_mode='categorical',
    subset='validation')
# Out:
# Found 442 images belonging to 6 classes.
# Found 109 images belonging to 6 classes.

# %% [markdown]
# ## Modelling

# %%
model = tf.keras.models.Sequential([
    # Note the input shape is the desired size of the image 150x150 with 3 bytes color
    tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(150, 150, 3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.4),
    # Flatten the results to feed into a DNN
    tf.keras.layers.Flatten(),
    # 512 neuron hidden layer
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 64)      1792
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        18464
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 32)        0
#  g2D)
#
#  dropout (Dropout)           (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 9642086 (36.78 MB)
# Trainable params: 9642086 (36.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### **[Additional ⚠️]** Callback

# %%
callback_cp = tf.keras.callbacks.ModelCheckpoint(
    filepath="/tmp/best-weights/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5", #hdf5 = h5 (versi singkat)
    monitor="val_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max"
)
callback_es = tf.keras.callbacks.EarlyStopping(monitor='loss', restore_best_weights=True, patience=7)

# %%
model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %% [markdown]
# ## Training Model

# %%
history = model.fit(
    train_generator,
    epochs=30,
    validation_data=validation_generator,
    verbose=1,
    callbacks=[callback_cp, callback_es]
)
# Out:
# Epoch 1/30
# 56/56 [==============================] - ETA: 0s - loss: 1.8681 - accuracy: 0.1878
# Epoch 1: val_accuracy improved from -inf to 0.15596, saving model to /tmp/best-weights/weights-improvement-01-0.16.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 56/56 [==============================] - 16s 179ms/step - loss: 1.8681 - accuracy: 0.1878 - val_loss: 1.7926 - val_accuracy: 0.1560
# Epoch 2/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7918 - accuracy: 0.1493
# Epoch 2: val_accuracy improved from 0.15596 to 0.18349, saving model to /tmp/best-weights/weights-improvement-02-0.18.hdf5
# 56/56 [==============================] - 8s 151ms/step - loss: 1.7918 - accuracy: 0.1493 - val_loss: 1.7890 - val_accuracy: 0.1835
# Epoch 3/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7853 - accuracy: 0.1833
# Epoch 3: val_accuracy did not improve from 0.18349
# 56/56 [==============================] - 7s 127ms/step - loss: 1.7853 - accuracy: 0.1833 - val_loss: 1.7854 - val_accuracy: 0.1835
# Epoch 4/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7787 - accuracy: 0.1923
# Epoch 4: val_accuracy did not improve from 0.18349
# 56/56 [==============================] - 9s 156ms/step - loss: 1.7787 - accuracy: 0.1923 - val_loss: 1.7853 - val_accuracy: 0.1835
# Epoch 5/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7787 - accuracy: 0.2149
# Epoch 5: val_accuracy improved from 0.18349 to 0.21101, saving model to /tmp/best-weights/weights-improvement-05-0.21.hdf5
# 56/56 [==============================] - 8s 151ms/step - loss: 1.7787 - accuracy: 0.2149 - val_loss: 1.7873 - val_accuracy: 0.2110
# Epoch 6/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7104 - accuracy: 0.2511
# Epoch 6: val_accuracy improved from 0.21101 to 0.24771, saving model to /tmp/best-weights/weights-improvement-06-0.25.hdf5
# 56/56 [==============================] - 7s 132ms/step - loss: 1.7104 - accuracy: 0.2511 - val_loss: 1.7506 - val_accuracy: 0.2477
# Epoch 7/30
# 56/56 [==============================] - ETA: 0s - loss: 1.7291 - accuracy: 0.2579
# Epoch 7: val_accuracy improved from 0.24771 to 0.26606, saving model to /tmp/best-weights/weights-improvement-07-0.27.hdf5
# 56/56 [==============================] - 7s 134ms/step - loss: 1.7291 - accuracy: 0.2579 - val_loss: 1.7447 - val_accuracy: 0.2661
# Epoch 8/30
# 56/56 [==============================] - ETA: 0s - loss: 1.6746 - accuracy: 0.2919
# Epoch 8: val_accuracy improved from 0.26606 to 0.29358, saving model to /tmp/best-weights/weights-improvement-08-0.29.hdf5
# 56/56 [==============================] - 9s 158ms/step - loss: 1.6746 - accuracy: 0.2919 - val_loss: 1.7128 - val_accuracy: 0.2936
# Epoch 9/30
# 56/56 [==============================] - ETA: 0s - loss: 1.6345 - accuracy: 0.2873
# Epoch 9: val_accuracy did not improve from 0.29358
# 56/56 [==============================] - 8s 153ms/step - loss: 1.6345 - accuracy: 0.2873 - val_loss: 1.6987 - val_accuracy: 0.2661
# Epoch 10/30
# 55/56 [============================>.] - ETA: 0s - loss: 1.5817 - accuracy: 0.3273
# Epoch 10: val_accuracy improved from 0.29358 to 0.33945, saving model to /tmp/best-weights/weights-improvement-10-0.34.hdf5
# 56/56 [==============================] - 7s 133ms/step - loss: 1.5809 - accuracy: 0.3281 - val_loss: 1.6786 - val_accuracy: 0.3394
# Epoch 11/30
# 56/56 [==============================] - ETA: 0s - loss: 1.5918 - accuracy: 0.3552
# Epoch 11: val_accuracy did not improve from 0.33945
# 56/56 [==============================] - 8s 151ms/step - loss: 1.5918 - accuracy: 0.3552 - val_loss: 1.7000 - val_accuracy: 0.2110
# Epoch 12/30
# 56/56 [==============================] - ETA: 0s - loss: 1.5253 - accuracy: 0.3688
# Epoch 12: val_accuracy improved from 0.33945 to 0.36697, saving model to /tmp/best-weights/weights-improvement-12-0.37.hdf5
# 56/56 [==============================] - 9s 154ms/step - loss: 1.5253 - accuracy: 0.3688 - val_loss: 1.6141 - val_accuracy: 0.3670
# Epoch 13/30
# 56/56 [==============================] - ETA: 0s - loss: 1.4960 - accuracy: 0.4186
# Epoch 13: val_accuracy improved from 0.36697 to 0.37615, saving model to /tmp/best-weights/weights-improvement-13-0.38.hdf5
# 56/56 [==============================] - 8s 139ms/step - loss: 1.4960 - accuracy: 0.4186 - val_loss: 1.6386 - val_accuracy: 0.3761
# Epoch 14/30
# 56/56 [==============================] - ETA: 0s - loss: 1.4359 - accuracy: 0.4276
# Epoch 14: val_accuracy improved from 0.37615 to 0.41284, saving model to /tmp/best-weights/weights-improvement-14-0.41.hdf5
# 56/56 [==============================] - 9s 156ms/step - loss: 1.4359 - accuracy: 0.4276 - val_loss: 1.6252 - val_accuracy: 0.4128
# Epoch 15/30
# 56/56 [==============================] - ETA: 0s - loss: 1.3883 - accuracy: 0.4638
# Epoch 15: val_accuracy improved from 0.41284 to 0.45872, saving model to /tmp/best-weights/weights-improvement-15-0.46.hdf5
# 56/56 [==============================] - 8s 149ms/step - loss: 1.3883 - accuracy: 0.4638 - val_loss: 1.5775 - val_accuracy: 0.4587
# Epoch 16/30
# 56/56 [==============================] - ETA: 0s - loss: 1.3468 - accuracy: 0.4796
# Epoch 16: val_accuracy did not improve from 0.45872
# 56/56 [==============================] - 7s 127ms/step - loss: 1.3468 - accuracy: 0.4796 - val_loss: 1.5906 - val_accuracy: 0.4128
# Epoch 17/30
# 56/56 [==============================] - ETA: 0s - loss: 1.3361 - accuracy: 0.4819
# Epoch 17: val_accuracy did not improve from 0.45872
# 56/56 [==============================] - 8s 152ms/step - loss: 1.3361 - accuracy: 0.4819 - val_loss: 1.6171 - val_accuracy: 0.3394
# Epoch 18/30
# 56/56 [==============================] - ETA: 0s - loss: 1.3203 - accuracy: 0.4887
# Epoch 18: val_accuracy did not improve from 0.45872
# 56/56 [==============================] - 8s 147ms/step - loss: 1.3203 - accuracy: 0.4887 - val_loss: 1.5772 - val_accuracy: 0.4128
# Epoch 19/30
# 56/56 [==============================] - ETA: 0s - loss: 1.2837 - accuracy: 0.5113
# Epoch 19: val_accuracy did not improve from 0.45872
# 56/56 [==============================] - 7s 126ms/step - loss: 1.2837 - accuracy: 0.5113 - val_loss: 1.5256 - val_accuracy: 0.4220
# Epoch 20/30
# 56/56 [==============================] - ETA: 0s - loss: 1.1914 - accuracy: 0.5588
# Epoch 20: val_accuracy improved from 0.45872 to 0.51376, saving model to /tmp/best-weights/weights-improvement-20-0.51.hdf5
# 56/56 [==============================] - 9s 154ms/step - loss: 1.1914 - accuracy: 0.5588 - val_loss: 1.4334 - val_accuracy: 0.5138
# Epoch 21/30
# 56/56 [==============================] - ETA: 0s - loss: 1.2044 - accuracy: 0.5113
# Epoch 21: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 8s 143ms/step - loss: 1.2044 - accuracy: 0.5113 - val_loss: 1.4958 - val_accuracy: 0.4220
# Epoch 22/30
# 56/56 [==============================] - ETA: 0s - loss: 1.1538 - accuracy: 0.5611
# Epoch 22: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 7s 126ms/step - loss: 1.1538 - accuracy: 0.5611 - val_loss: 1.4941 - val_accuracy: 0.4037
# Epoch 23/30
# 56/56 [==============================] - ETA: 0s - loss: 1.0666 - accuracy: 0.5860
# Epoch 23: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 7s 125ms/step - loss: 1.0666 - accuracy: 0.5860 - val_loss: 1.4408 - val_accuracy: 0.5046
# Epoch 24/30
# 56/56 [==============================] - ETA: 0s - loss: 1.0609 - accuracy: 0.5860
# Epoch 24: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 8s 150ms/step - loss: 1.0609 - accuracy: 0.5860 - val_loss: 1.3681 - val_accuracy: 0.5138
# Epoch 25/30
# 56/56 [==============================] - ETA: 0s - loss: 0.9853 - accuracy: 0.6131
# Epoch 25: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 8s 140ms/step - loss: 0.9853 - accuracy: 0.6131 - val_loss: 1.4518 - val_accuracy: 0.5138
# Epoch 26/30
# 56/56 [==============================] - ETA: 0s - loss: 0.9627 - accuracy: 0.6538
# Epoch 26: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 7s 132ms/step - loss: 0.9627 - accuracy: 0.6538 - val_loss: 1.5030 - val_accuracy: 0.4679
# Epoch 27/30
# 56/56 [==============================] - ETA: 0s - loss: 0.8575 - accuracy: 0.7014
# Epoch 27: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 8s 151ms/step - loss: 0.8575 - accuracy: 0.7014 - val_loss: 1.4959 - val_accuracy: 0.4954
# Epoch 28/30
# 56/56 [==============================] - ETA: 0s - loss: 0.9594 - accuracy: 0.6516
# Epoch 28: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 7s 128ms/step - loss: 0.9594 - accuracy: 0.6516 - val_loss: 1.5425 - val_accuracy: 0.5046
# Epoch 29/30
# 56/56 [==============================] - ETA: 0s - loss: 0.8130 - accuracy: 0.7014
# Epoch 29: val_accuracy did not improve from 0.51376
# 56/56 [==============================] - 7s 128ms/step - loss: 0.8130 - accuracy: 0.7014 - val_loss: 1.6439 - val_accuracy: 0.4587
# Epoch 30/30
# 56/56 [==============================] - ETA: 0s - loss: 0.7721 - accuracy: 0.7014
# Epoch 30: val_accuracy improved from 0.51376 to 0.55046, saving model to /tmp/best-weights/weights-improvement-30-0.55.hdf5
# 56/56 [==============================] - 9s 155ms/step - loss: 0.7721 - accuracy: 0.7014 - val_loss: 1.6226 - val_accuracy: 0.5505

# %% [markdown]
# ## Visualization: Accuracy and Loss

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='accuracy Training ')
plt.plot(epochs, val_acc, 'b', label='accuracy Validasi')
plt.title('accuracy Training and Validasi')
plt.legend(loc=0)
plt.figure()
plt.show()

plt.plot(epochs, loss, 'r', label='loss Training ')
plt.plot(epochs, val_loss, 'b', label='loss Validasi')
plt.title('loss Training and Validasi')
plt.legend(loc=0)
plt.figure()
plt.show()

# %% [markdown]
# ## **[Additional ✅]** Test Accuracy Model

# %%
val_loss_acc = model.evaluate(validation_generator, steps=len(validation_generator))
# Out:
# 7/7 [==============================] - 3s 387ms/step - loss: 1.6226 - accuracy: 0.5505

# %% [markdown]
# ## Export Model to TFLite

# %%
# Menyimpan model dalam format SavedModel
export_dir = 'saved_model/'
tf.saved_model.save(model, export_dir)

# Convert SavedModel menjadi vegs.tflite
converter = tf.lite.TFLiteConverter.from_saved_model(export_dir)
tflite_model = converter.convert()

tflite_model_file = pathlib.Path('chess.tflite')
tflite_model_file.write_bytes(tflite_model)
# Out:
# 38572856

# %%
tflite_model_size = len(tflite_model) / (1024 * 1024)
print('TFLite model size = %d MBs.' % tflite_model_size)
# Out:
# TFLite model size = 36 MBs.

# %% [markdown]
# ## **[Additional ⚠️]** Optimization TFLite

# %% [markdown]
# ### Quantization

# %% [markdown]
# References:
# - https://www.tensorflow.org/lite/performance/model_optimization
# - (old version): https://www.tensorflow.org/api_docs/python/tf/lite/Optimize
# - (new version): https://www.tensorflow.org/lite/performance/post_training_quantization

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### [Dynamic Range] Quantization default - decreased around 75%

# %%
# Convert Keras model to TF Lite format.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quantdefault_model = converter.convert()

os.mkdir("/content/model-tflite-quantdefault")
f = open('/content/model-tflite-quantdefault/model.tflite', "wb")
f.write(tflite_quantdefault_model)
f.close()

# %%
size_tflite_quantdefault = len(tflite_quantdefault_model) / (1024 * 1024)
print('TFLite quant model size = %d MBs.' % size_tflite_quantdefault)
print(f"Decreased : {(tflite_model_size - size_tflite_quantdefault) / tflite_model_size * 100} %")
# Out:
# TFLite quant model size = 9 MBs.
# Decreased : 74.97840450289706 %

# %% [markdown]
# ## **[Additional ⚠️]** Test and Evaluate with TFLite Interpreter

# %%
import random
import numpy as np
# Take a sample batch file
idx_val = random.randrange(len(validation_generator))
list_test_img, list_test_lb = validation_generator[idx_val]

# %%
def evaluate_tflite_model(tflite_model):
  # Initialize TFLite interpreter using the model.
  interpreter = tf.lite.Interpreter(model_content=tflite_model)
  interpreter.allocate_tensors()

  input_details = interpreter.get_input_details()[0]
  output_details = interpreter.get_output_details()[0]

  # Run predictions on every image in the "test" dataset.
  predictions = []
  for test_image in list_test_img:

    # [FIXED] Input data type error, Previous error of type tf.float32, it should be tf.int8
    # Check if the input type is quantized, then rescale input data to uint8
    # ref : https://www.tensorflow.org/lite/performance/post_training_integer_quant
    if input_details['dtype'] == np.uint8:
      input_scale, input_zero_point = input_details["quantization"]
      test_image = test_image / input_scale + input_zero_point

    # Pre-processing: add batch dimension and convert to float32 to match with
    # the model's input data format.
    test_image = np.expand_dims(test_image, axis=0).astype(input_details["dtype"])
    interpreter.set_tensor(input_details["index"], test_image)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details["index"])[0]

    # Post-processing: remove batch dimension and find the digit with highest probability.
    predictions.append(output.argmax())

  # Compare prediction results with ground truth labels to calculate accuracy.
  accurate_count = 0
  for index in range(len(predictions)):
    if predictions[index] == np.argmax(list_test_lb[index]):
      accurate_count += 1
  accuracy = accurate_count * 1.0 / len(predictions)

  return accuracy

# %%
# Evaluate the TF Lite float model.
float_accuracy = evaluate_tflite_model(tflite_model)
print('Float model accuracy = %.4f' % float_accuracy)

# Evalualte the TF Lite quantized model.
quantized_accuracy = evaluate_tflite_model(tflite_quantdefault_model)
print('Quantized model accuracy = %.4f' % quantized_accuracy)
gap_acc = float_accuracy - quantized_accuracy
if gap_acc >= 0:
  print('Accuracy drop = %.4f' % (gap_acc))
else:
  print('Accuracy increase = %.4f' % (-1*gap_acc))
# Out:
# Float model accuracy = 0.6875
# Quantized model accuracy = 0.6875
# Accuracy drop = 0.0000

# %% [markdown]
# ## Feel free untuk tanya / diskusi melalui grup atau japri fasil (Kak Galang) via WA ya 🙌
